# %% [markdown]
# <a href="https://colab.research.google.com/github/Supraja-Kurapati/GenAi/blob/main/Gen_Ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install all required dependencies
# !pip install -q transformers datasets tokenizers accelerate peft trl evaluate huggingface_hub bitsandbytes sentence-transformers optimum langchain langchain-community llama-index faiss-cpu chromadb openai anthropic groq tiktoken

print("\n--- Installation Complete! ---")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.0/889.0 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.1/559.1 kB 44.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 94.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 99.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 84.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 26.3 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import notebook_login

# This creates an interactive login box inside Colab
notebook_login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>48FF-XCRN</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>Supraja58</b> (token: <code>oauth-Supraja58</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
import sys
import torch

print("=" * 50)
print("           QUICK ENVIRONMENT CHECK")
print("=" * 50)

# Check PyTorch & CUDA GPU
print(f"PyTorch Version: {torch.__version__}")
if torch.cuda.is_available():
    print(f"CUDA GPU Active: {torch.cuda.get_device_name(0)}")
else:
    print("GPU Status: Not enabled (Go to Runtime -> Change runtime type -> T4 GPU)")

# Check Core Installed LLM Packages
packages = ["transformers", "datasets", "accelerate", "peft", "langchain", "llama_index"]
for pkg in packages:
    try:
        mod = __import__(pkg)
        print(f"[OK] {pkg} version: {getattr(mod, '__version__', 'Installed')}")
    except ImportError as e:
        print(f"[FAILED] {pkg}: {e}")

print("=" * 50)
# Out:
# ...
#            QUICK ENVIRONMENT CHECK
# ...
# PyTorch Version: 2.11.0+cu128
# CUDA GPU Active: Tesla T4
# [OK] transformers version: 5.13.1
# [OK] datasets version: 5.0.1
# [OK] accelerate version: 1.14.0
# [OK] peft version: 0.19.1
# [OK] langchain version: 1.3.13
# [OK] llama_index version: Installed
# ...
